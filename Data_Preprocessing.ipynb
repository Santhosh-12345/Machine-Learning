# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
file_path = "Salary_dataset 1.csv" 
df = pd.read_csv(file_path)
print(df.columns)
column_name = 'Salary'
five_num_summary = df[column_name].describe().loc[['min', '25%', '50%', '75%', 'max']]
print("Five-Number Summary:\n",five_num_summary)
plt.figure(figsize=(8, 6))
plt.boxplot(df[column_name], vert=True, patch_artist=True)
plt.title(f'Box Plot of {column_name}')
plt.ylabel(column_name)
plt.grid(True)
plt.show()
# Out:
# Index(['Unnamed: 0', 'YearsExperience', 'Salary'], dtype='object')
# Five-Number Summary:
#  min     37732.00
# 25%     56721.75
# 50%     65238.00
# 75%    100545.75
# max    122392.00
# Name: Salary, dtype: float64

# %%
import pandas as pd
df = pd.read_excel("Missing_Values.xlsx")

print("Original Dataset:\n", df)

print("\nMissing Values Count:\n", df.isnull().sum())

df_dropna = df.dropna()
print("\nDataset after Dropping Rows with Missing Values:\n", df_dropna)
# Out:
# Original Dataset:
#        Name   Age   Salary Department
# 0    Alice  25.0  50000.0         HR
# 1      Bob   NaN  60000.0         IT
# 2  Charlie  30.0      NaN        NaN
# 3    David  22.0  45000.0    Finance
# 4      Eve   NaN  70000.0  Marketing
# 5     Mary  30.0      NaN        NaN
# 6   Thomas  32.0  50000.0   Computer
#
# Missing Values Count:
#  Name          0
# Age           2
# Salary        2
# Department    2
# dtype: int64
#
# Dataset after Dropping Rows with Missing Values:
#       Name   Age   Salary Department
# 0   Alice  25.0  50000.0         HR
# 3   David  22.0  45000.0    Finance
# 6  Thomas  32.0  50000.0   Computer

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
file_path = "Salary_dataset 1.csv"  
df = pd.read_csv(file_path,index_col=0)
print(df.head())
x = np.array(df["YearsExperience"]).reshape(-1, 1)  
y = np.array(df["Salary"])  
model = LinearRegression()
model.fit(x, y)
y_pred = model.predict(x)
cov = np.cov(x.flatten(), y.flatten()) 
covariance = cov[0, 1]
print(f"Covariance between Years of Experience and Salary: {covariance}")
correlation_matrix = np.corrcoef(x.flatten(), y.flatten())  
correlation_value = correlation[0, 1]
print(f"Correlation between Years of Experience and Salary: {correlation_value}")
mse = mean_squared_error(y, y_pred)
r2 = r2_score(y, y_pred)
print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
plt.scatter(x, y, color='blue', label='Data points')  
plt.plot(x, y_pred, color='red', label='Regression line')  
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Linear Regression: Experience vs Salary')
plt.legend()
plt.show()
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0
# Covariance between Years of Experience and Salary: 76106.30344827585
# Correlation between Years of Experience and Salary: 0.9782416184887599
# Mean Squared Error: 31270951.722280957
# R-squared: 0.9569566641435086
